# %% [markdown]
# ### OpenParse

# %%
import json
import time
import os
import pandas as pd
from dotenv import load_dotenv
from langchain.retrievers.contextual_compression import ContextualCompressionRetriever
from langchain_cohere import CohereRerank
from langchain_community.vectorstores import PathwayVectorClient
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains import LLMChain
import tiktoken  # For token counting

# Load environment variables
def load_environment_variables():
    """Load environment variables from a .env file."""
    print("Loading environment variables...")
    load_dotenv()
    os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
    print("Environment variables loaded.")

# Initialize Pathway retriever
def create_pathway_client(host="127.0.0.1", port=8011, k=10):
    """Initialize PathwayVectorClient and return as retriever."""
    print(f"Initializing PathwayVectorClient on host {host} and port {port}...")
    client = PathwayVectorClient(host=host, port=port)
    print("PathwayVectorClient initialized.")
    return client.as_retriever(search_kwargs={"k": k})

# Retrieve relevant documents
def retrieve_relevant_documents(retriever, query):
    """Retrieve relevant documents based on the given query."""
    print(f"Retrieving relevant documents for query: {query}")
    try:
        docs = retriever.get_relevant_documents(query)
        print(f"Retrieved {len(docs)} chunks.")
        return docs
    except Exception as e:
        print(f"Error retrieving documents: {e}")
        return []

# Create document compressor
def create_compressor(model="rerank-english-v3.0"):
    """Create and return a CohereRerank compressor."""
    print("Creating CohereRerank compressor...")
    compressor = CohereRerank(model=model, top_n=5)
    print("Compressor created.")
    return compressor

# Compress retrieved documents
def compress_documents(retriever, query, compressor):
    """Compress relevant documents using the provided compressor."""
    print("Compressing retrieved chunks...")
    compression_retriever = ContextualCompressionRetriever(
        base_compressor=compressor, base_retriever=retriever
    )
    try:
        compressed_docs = compression_retriever.invoke(query)
        print(f"Compressed to {len(compressed_docs)} chunks.")
        return compressed_docs
    except Exception as e:
        print(f"Error during compression: {e}")
        return []

# Initialize OpenAI LLM
def create_llm():
    """Create and return an OpenAI LLM instance."""
    print("Initializing OpenAI LLM...")
    llm = ChatOpenAI(
        model="gpt-4o-mini",
        temperature=0,
        max_tokens=None,
        timeout=45,
        max_retries=2,
    )
    print("OpenAI LLM initialized.")
    return llm

# Create ChatPromptTemplate for Q&A
def create_chat_prompt():
    """Create and return a chat prompt template for Q&A."""
    print("Creating chat prompt template...")
    chat_prompt = ChatPromptTemplate.from_messages(
        [
            (
                "system",
                "You are a helpful assistant. Answer the following question based only on the provided context.\n"
                "Provide a step-by-step explanation, and reference the source details using metadata.\n\n"
                "<context>\n{context}\n</context>",
            ),
            ("human", "{question}"),
        ]
    )
    print("Chat prompt template created.")
    return chat_prompt

# Token counting function
def count_tokens(text, model="o200k_base"):
    """Estimate token count for given text using tiktoken."""
    tokenizer = tiktoken.get_encoding(model)
    tokens = tokenizer.encode(text)
    return len(tokens)

# Generate answer
def get_answer(context, question, chain):
    """Generate an answer based on the context and question using the LLM chain."""
    print("Generating answer for the question...")
    try:
        input_tokens = count_tokens(context) + count_tokens(question)
        print(f"Estimated input tokens: {input_tokens}")

        # Invoke the LLM chain with structured input
        answer = chain.invoke({"context": context, "question": question})
        
        output_tokens = count_tokens(answer.content)
        print(f"Estimated output tokens: {output_tokens}")
        
        return answer.content
    except Exception as e:
        print(f"Error generating answer: {e}")
        return None

# Main execution logic
def main():
    # Load environment variables
    load_environment_variables()

    # Load the dataset
    file_path = 'AAPL_10Q_dataset/aapl_qna_data.csv'
    print(f"Loading dataset from {file_path}...")
    data = pd.read_csv(file_path)
    print(f"Loaded {len(data)} questions.")

    # Initialize Pathway retriever, compressor, LLM, and chat prompt
    retriever = create_pathway_client()
    compressor = create_compressor()
    llm = create_llm()
    chat_prompt = create_chat_prompt()

    # Create the LLM chain
    chain = chat_prompt | llm

    # Prepare results storage
    results = []
    print("Total number of rows: ", len(data))
    # Loop over each question in the dataset
    for idx, row in data.iterrows():
        question = row['Question']
        gt_answer = row.get('Answer', "Ground truth answer not provided")
        
        print(f"\nProcessing question ID {idx}: {question}")

        # Step 1: Retrieve relevant documents
        retrieved_docs = retrieve_relevant_documents(retriever, question)
        if not retrieved_docs:
            print(f"No documents retrieved for query ID {idx}.")
            continue

        # Step 2: Compress retrieved documents
        compressed_docs = compress_documents(retriever, question, compressor)
        # compressed_docs = retrieved_docs

        # Prepare the context from compressed documents
        context = "\n".join([doc.page_content for doc in compressed_docs if doc.page_content])

        # Step 3: Generate an answer with retry logic
        answer = get_answer(context, question, chain)
        if answer is None:
            print(f"Retrying for question ID {idx} due to no initial response...")
            time.sleep(50)  # Wait 50 seconds before retrying
            answer = get_answer(context, question, chain)

        # Structure retrieved context in a list of dictionaries as per your format
        retrieved_context = [
            {"doc_id": doc.metadata.get("doc_id", "unknown"), "text": doc.page_content}
            for doc in compressed_docs
        ]
        
        # Append to results
        results.append({
            "query_id": str(idx).zfill(3),
            "question": question,
            "gt_answer": gt_answer,
            "response": answer,
            "retrieved_context": retrieved_context
        })

    # Save the results to a JSON file
    output_path = 'eval_results/basic_rag_openParser.json'
    print(f"Saving evaluation results to {output_path}...")
    with open(output_path, 'w') as f:
        json.dump({"results": results}, f, indent=4)

    print(f"Evaluation results saved to {output_path}")

# Run main function
if __name__ == "__main__":
    main()
# Out:
# Loading environment variables...
# Environment variables loaded.
# Loading dataset from AAPL_10Q_dataset/aapl_qna_data.csv...
# Loaded 39 questions.
# Initializing PathwayVectorClient on host 127.0.0.1 and port 8011...
# PathwayVectorClient initialized.
# Creating CohereRerank compressor...
# Compressor created.
# Initializing OpenAI LLM...
# OpenAI LLM initialized.
# Creating chat prompt template...
# Chat prompt template created.
# Total number of rows:  39
#
# Processing question ID 0: How has Apple's total net sales changed over time?
# Retrieving relevant documents for query: How has Apple's total net sales changed over time?
# /tmp/ipykernel_121405/4019836350.py:35: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   docs = retriever.get_relevant_documents(query)
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 2005
# Estimated output tokens: 465
#
# Processing question ID 1: What are the major factors contributing to the change in Apple's gross margin in the most recent 10-Q compared to the previous quarters?
# Retrieving relevant documents for query: What are the major factors contributing to the change in Apple's gross margin in the most recent 10-Q compared to the previous quarters?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 446
# Estimated output tokens: 434
#
# Processing question ID 2: Has there been any significant change in Apple's operating expenses over the reported quarters? If so, what are the key drivers for this change?
# Retrieving relevant documents for query: Has there been any significant change in Apple's operating expenses over the reported quarters? If so, what are the key drivers for this change?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 1904
# Estimated output tokens: 384
#
# Processing question ID 3: How has Apple's revenue from iPhone sales fluctuated across quarters?
# Retrieving relevant documents for query: How has Apple's revenue from iPhone sales fluctuated across quarters?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 1733
# Estimated output tokens: 301
#
# Processing question ID 4: Can any trends be identified in Apple's Services segment revenue over the reported periods?
# Retrieving relevant documents for query: Can any trends be identified in Apple's Services segment revenue over the reported periods?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 1586
# Estimated output tokens: 352
#
# Processing question ID 5: What is the impact of foreign exchange rates on Apple's financial performance? List this out separately for each reported period.
# Retrieving relevant documents for query: What is the impact of foreign exchange rates on Apple's financial performance? List this out separately for each reported period.
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 1638
# Estimated output tokens: 189
#
# Processing question ID 6: Are there any notable changes in Apple's liquidity position or cash flows as reported in these 10-Qs?
# Retrieving relevant documents for query: Are there any notable changes in Apple's liquidity position or cash flows as reported in these 10-Qs?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 105
# Estimated output tokens: 313
#
# Processing question ID 7: How does Apple's R&D expenditure in the most recent quarter compare to previous quarters and what implications might this have?
# Retrieving relevant documents for query: How does Apple's R&D expenditure in the most recent quarter compare to previous quarters and what implications might this have?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 592
# Estimated output tokens: 125
#
# Processing question ID 8: What legal proceedings or contingencies are disclosed in these 10-Qs and how might they potentially impact Apple?
# Retrieving relevant documents for query: What legal proceedings or contingencies are disclosed in these 10-Qs and how might they potentially impact Apple?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 106
# Estimated output tokens: 291
#
# Processing question ID 9: Has Apple engaged in any significant share repurchase activities in the reported quarters and what are the financial implications of these activities?
# Retrieving relevant documents for query: Has Apple engaged in any significant share repurchase activities in the reported quarters and what are the financial implications of these activities?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 867
# Estimated output tokens: 469
#
# Processing question ID 10: What is the effective tax rate reported by Apple in these quarters and how does it compare across the periods?
# Retrieving relevant documents for query: What is the effective tax rate reported by Apple in these quarters and how does it compare across the periods?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 105
# Estimated output tokens: 171
#
# Processing question ID 11: Does Apple report any significant new business acquisitions or divestitures in these 10-Qs?
# Retrieving relevant documents for query: Does Apple report any significant new business acquisitions or divestitures in these 10-Qs?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 103
# Estimated output tokens: 281
#
# Processing question ID 12: How have Apple's inventory levels changed across these quarters and what might this indicate about their supply chain management?
# Retrieving relevant documents for query: How have Apple's inventory levels changed across these quarters and what might this indicate about their supply chain management?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 1424
# Estimated output tokens: 443
#
# Processing question ID 13: Are there any significant changes or new disclosures in Apple's accounting policies as reported in these 10-Qs?
# Retrieving relevant documents for query: Are there any significant changes or new disclosures in Apple's accounting policies as reported in these 10-Qs?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 105
# Estimated output tokens: 296
#
# Processing question ID 14: Summarize the risk factors to Apple's business, and how they have changed over the reporting period
# Retrieving relevant documents for query: Summarize the risk factors to Apple's business, and how they have changed over the reporting period
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 2292
# Estimated output tokens: 436
#
# Processing question ID 15: What was the gross margin for Apple in the latest 10-Q report?
# Retrieving relevant documents for query: What was the gross margin for Apple in the latest 10-Q report?
# Error retrieving documents: HTTPConnectionPool(host='127.0.0.1', port=8011): Read timed out. (read timeout=3)
# No documents retrieved for query ID 15.
#
# Processing question ID 16: How did Apple's operating expenses for Q1 2023 compare to its revenue for the same quarter?
# Retrieving relevant documents for query: How did Apple's operating expenses for Q1 2023 compare to its revenue for the same quarter?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 254
# Estimated output tokens: 123
#
# Processing question ID 17: In the second quarter of 2023, what was the primary driver behind the change in Apple's net income?
# Retrieving relevant documents for query: In the second quarter of 2023, what was the primary driver behind the change in Apple's net income?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 1041
# Estimated output tokens: 150
#
# Processing question ID 18: For the latest quarter, what was the total revenue generated from Apple's iPhone sales?
# Retrieving relevant documents for query: For the latest quarter, what was the total revenue generated from Apple's iPhone sales?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 1317
# Estimated output tokens: 144
#
# Processing question ID 19: What percentage of Apple's total revenue did the Services segment contribute in Q3 2023?
# Retrieving relevant documents for query: What percentage of Apple's total revenue did the Services segment contribute in Q3 2023?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 972
# Estimated output tokens: 82
#
# Processing question ID 20: How did foreign exchange rates specifically affect Apple's financial performance in the most recent 10-Q?
# Retrieving relevant documents for query: How did foreign exchange rates specifically affect Apple's financial performance in the most recent 10-Q?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 438
# Estimated output tokens: 243
#
# Processing question ID 21: What was Apple's cash flow from operating activities as reported in the Q3 2022 10-Q?
# Retrieving relevant documents for query: What was Apple's cash flow from operating activities as reported in the Q3 2022 10-Q?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 105
# Estimated output tokens: 146
#
# Processing question ID 22: In the first quarter of 2023, how much did Apple spend on research and development, and what was the focus of this expenditure?
# Retrieving relevant documents for query: In the first quarter of 2023, how much did Apple spend on research and development, and what was the focus of this expenditure?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 262
# Estimated output tokens: 80
#
# Processing question ID 23: What specific legal proceedings or potential liabilities were mentioned in Apple's Q2 2023 10-Q, and what is their potential impact?
# Retrieving relevant documents for query: What specific legal proceedings or potential liabilities were mentioned in Apple's Q2 2023 10-Q, and what is their potential impact?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 111
# Estimated output tokens: 359
#
# Processing question ID 24: Did Apple report any share repurchase activities in its Q3 2023 10-Q, and if so, what was the scale of these buybacks?
# Retrieving relevant documents for query: Did Apple report any share repurchase activities in its Q3 2023 10-Q, and if so, what was the scale of these buybacks?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 116
# Estimated output tokens: 224
#
# Processing question ID 25: What changes in debt structure or interest expenses did Apple disclose in the Q1 2023 10-Q?
# Retrieving relevant documents for query: What changes in debt structure or interest expenses did Apple disclose in the Q1 2023 10-Q?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 106
# Estimated output tokens: 276
#
# Processing question ID 26: What effective tax rate did Apple report in its latest quarterly filing, and how does this compare to the statutory tax rate?
# Retrieving relevant documents for query: What effective tax rate did Apple report in its latest quarterly filing, and how does this compare to the statutory tax rate?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Error during compression: status_code: 429, body: data=None message="You are using a Trial key, which is limited to 10 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"
# Generating answer for the question...
# Estimated input tokens: 24
# Estimated output tokens: 160
#
# Processing question ID 27: Were there any significant acquisitions or divestitures reported by Apple in the Q2 2023 10-Q?
# Retrieving relevant documents for query: Were there any significant acquisitions or divestitures reported by Apple in the Q2 2023 10-Q?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 107
# Estimated output tokens: 249
#
# Processing question ID 28: How did Apple's inventory levels in the Q3 2022 report reflect on their supply chain efficiency?
# Retrieving relevant documents for query: How did Apple's inventory levels in the Q3 2022 report reflect on their supply chain efficiency?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 104
# Estimated output tokens: 360
#
# Processing question ID 29: What significant accounting policy changes, if any, did Apple disclose in its most recent 10-Q?
# Retrieving relevant documents for query: What significant accounting policy changes, if any, did Apple disclose in its most recent 10-Q?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 104
# Estimated output tokens: 203
#
# Processing question ID 30: In Apple's Q1 2023 10-Q, what is the correlation between Apple's R&D expenditure and the new products or services introduced by the company?
# Retrieving relevant documents for query: In Apple's Q1 2023 10-Q, what is the correlation between Apple's R&D expenditure and the new products or services introduced by the company?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 116
# Estimated output tokens: 291
#
# Processing question ID 31: For Apple's Q2 2023 report, analyze the relationship between Apple's revenue from international markets and its segment on foreign currency risk to understand the company's exposure to currency fluctuations.
# Retrieving relevant documents for query: For Apple's Q2 2023 report, analyze the relationship between Apple's revenue from international markets and its segment on foreign currency risk to understand the company's exposure to currency fluctuations.
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 119
# Estimated output tokens: 380
#
# Processing question ID 32: From Apple's most recent 10-Q, how do the insights from the liquidity and capital resources section correlate with the reported changes in Apple's cash flow from operations?
# Retrieving relevant documents for query: From Apple's most recent 10-Q, how do the insights from the liquidity and capital resources section correlate with the reported changes in Apple's cash flow from operations?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 116
# Estimated output tokens: 394
#
# Processing question ID 33: In Apple's Q3 2023 10-Q, analyze how the reported changes in Apple's inventory levels relate to the discussion in their supply chain and logistics section.
# Retrieving relevant documents for query: In Apple's Q3 2023 10-Q, analyze how the reported changes in Apple's inventory levels relate to the discussion in their supply chain and logistics section.
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 117
# Estimated output tokens: 457
#
# Processing question ID 34: From the latest 10-Q, how does Apple's discussion on market risk in the financial section align with the risk factors mentioned in the company's business overview?
# Retrieving relevant documents for query: From the latest 10-Q, how does Apple's discussion on market risk in the financial section align with the risk factors mentioned in the company's business overview?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 1967
# Estimated output tokens: 397
#
# Processing question ID 35: In Apple's Q1 2023 10-Q, combine the data on Apple's debt instruments from the financial statements with the management discussion to understand their debt management strategy.
# Retrieving relevant documents for query: In Apple's Q1 2023 10-Q, combine the data on Apple's debt instruments from the financial statements with the management discussion to understand their debt management strategy.
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 118
# Estimated output tokens: 441
#
# Processing question ID 36: In the most recent 10-Q, analyze how Apple's reported tax rate in the financial statements section correlates with the discussion on tax contingencies in the notes.
# Retrieving relevant documents for query: In the most recent 10-Q, analyze how Apple's reported tax rate in the financial statements section correlates with the discussion on tax contingencies in the notes.
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 117
# Estimated output tokens: 414
#
# Processing question ID 37: From Apple's Q3 2023 10-Q, how does the information in the operational expenses section relate to the insights shared in Apple's segment reporting?
# Retrieving relevant documents for query: From Apple's Q3 2023 10-Q, how does the information in the operational expenses section relate to the insights shared in Apple's segment reporting?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 115
# Estimated output tokens: 385
#
# Processing question ID 38: In the latest 10-Q, how does the revenue from new product launches by Apple compare with the company's marketing and advertising expenses?
# Retrieving relevant documents for query: In the latest 10-Q, how does the revenue from new product launches by Apple compare with the company's marketing and advertising expenses?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 1602
# Estimated output tokens: 155
# Saving evaluation results to eval_results/basic_rag_openParser.json...
# Evaluation results saved to eval_results/basic_rag_openParser.json

# %% [markdown]
# ### Our Parser

# %%
import json
import time
import os
import pandas as pd
from dotenv import load_dotenv
from langchain.retrievers.contextual_compression import ContextualCompressionRetriever
from langchain_cohere import CohereRerank
from langchain_community.vectorstores import PathwayVectorClient
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains import LLMChain
import tiktoken  # For token counting

# Load environment variables
def load_environment_variables():
    """Load environment variables from a .env file."""
    print("Loading environment variables...")
    load_dotenv()
    os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
    print("Environment variables loaded.")

# Initialize Pathway retriever
def create_pathway_client(host="127.0.0.1", port=8011, k=10):
    """Initialize PathwayVectorClient and return as retriever."""
    print(f"Initializing PathwayVectorClient on host {host} and port {port}...")
    client = PathwayVectorClient(host=host, port=port)
    print("PathwayVectorClient initialized.")
    return client.as_retriever(search_kwargs={"k": k})

# Retrieve relevant documents
def retrieve_relevant_documents(retriever, query):
    """Retrieve relevant documents based on the given query."""
    print(f"Retrieving relevant documents for query: {query}")
    try:
        docs = retriever.get_relevant_documents(query)
        print(f"Retrieved {len(docs)} chunks.")
        return docs
    except Exception as e:
        print(f"Error retrieving documents: {e}")
        return []

# Create document compressor
def create_compressor(model="rerank-english-v3.0"):
    """Create and return a CohereRerank compressor."""
    print("Creating CohereRerank compressor...")
    compressor = CohereRerank(model=model, top_n=5)
    print("Compressor created.")
    return compressor

# Compress retrieved documents
def compress_documents(retriever, query, compressor):
    """Compress relevant documents using the provided compressor."""
    print("Compressing retrieved chunks...")
    compression_retriever = ContextualCompressionRetriever(
        base_compressor=compressor, base_retriever=retriever
    )
    try:
        compressed_docs = compression_retriever.invoke(query)
        print(f"Compressed to {len(compressed_docs)} chunks.")
        return compressed_docs
    except Exception as e:
        print(f"Error during compression: {e}")
        return []

# Initialize OpenAI LLM
def create_llm():
    """Create and return an OpenAI LLM instance."""
    print("Initializing OpenAI LLM...")
    llm = ChatOpenAI(
        model="gpt-4o-mini",
        temperature=0,
        max_tokens=None,
        timeout=45,
        max_retries=2,
    )
    print("OpenAI LLM initialized.")
    return llm

# Create ChatPromptTemplate for Q&A
def create_chat_prompt():
    """Create and return a chat prompt template for Q&A."""
    print("Creating chat prompt template...")
    chat_prompt = ChatPromptTemplate.from_messages(
        [
            (
                "system",
                "You are a helpful assistant. Answer the following question based only on the provided context.\n"
                "Provide a step-by-step explanation, and reference the source details using metadata.\n\n"
                "<context>\n{context}\n</context>",
            ),
            ("human", "{question}"),
        ]
    )
    print("Chat prompt template created.")
    return chat_prompt

# Token counting function
def count_tokens(text, model="o200k_base"):
    """Estimate token count for given text using tiktoken."""
    tokenizer = tiktoken.get_encoding(model)
    tokens = tokenizer.encode(text)
    return len(tokens)

# Generate answer
def get_answer(context, question, chain):
    """Generate an answer based on the context and question using the LLM chain."""
    print("Generating answer for the question...")
    try:
        input_tokens = count_tokens(context) + count_tokens(question)
        print(f"Estimated input tokens: {input_tokens}")

        # Invoke the LLM chain with structured input
        answer = chain.invoke({"context": context, "question": question})
        
        output_tokens = count_tokens(answer.content)
        print(f"Estimated output tokens: {output_tokens}")
        
        return answer.content
    except Exception as e:
        print(f"Error generating answer: {e}")
        return None

# Main execution logic
def main():
    # Load environment variables
    load_environment_variables()

    # Load the dataset
    file_path = 'AAPL_10Q_dataset/aapl_qna_data.csv'
    print(f"Loading dataset from {file_path}...")
    data = pd.read_csv(file_path)
    print(f"Loaded {len(data)} questions.")

    # Initialize Pathway retriever, compressor, LLM, and chat prompt
    retriever = create_pathway_client()
    compressor = create_compressor()
    llm = create_llm()
    chat_prompt = create_chat_prompt()

    # Create the LLM chain
    chain = chat_prompt | llm

    # Prepare results storage
    results = []
    print("Total number of rows: ", len(data))
    # Loop over each question in the dataset
    for idx, row in data.iterrows():
        question = row['Question']
        gt_answer = row.get('Answer', "Ground truth answer not provided")
        
        print(f"\nProcessing question ID {idx}: {question}")

        # Step 1: Retrieve relevant documents
        retrieved_docs = retrieve_relevant_documents(retriever, question)
        if not retrieved_docs:
            print(f"No documents retrieved for query ID {idx}.")
            continue

        # Step 2: Compress retrieved documents
        compressed_docs = compress_documents(retriever, question, compressor)
        # compressed_docs = retrieved_docs

        # Prepare the context from compressed documents
        context = "\n".join([doc.page_content for doc in compressed_docs if doc.page_content])

        # Step 3: Generate an answer with retry logic
        answer = get_answer(context, question, chain)
        if answer is None:
            print(f"Retrying for question ID {idx} due to no initial response...")
            time.sleep(50)  # Wait 50 seconds before retrying
            answer = get_answer(context, question, chain)

        # Structure retrieved context in a list of dictionaries as per your format
        retrieved_context = [
            {"doc_id": doc.metadata.get("doc_id", "unknown"), "text": doc.page_content}
            for doc in compressed_docs
        ]
        
        # Append to results
        results.append({
            "query_id": str(idx).zfill(3),
            "question": question,
            "gt_answer": gt_answer,
            "response": answer,
            "retrieved_context": retrieved_context
        })

    # Save the results to a JSON file
    output_path = 'eval_results/basic_rag_enhancedParser.json'
    print(f"Saving evaluation results to {output_path}...")
    with open(output_path, 'w') as f:
        json.dump({"results": results}, f, indent=4)

    print(f"Evaluation results saved to {output_path}")

# Run main function
if __name__ == "__main__":
    main()
# Out:
# Loading environment variables...
# Environment variables loaded.
# Loading dataset from AAPL_10Q_dataset/aapl_qna_data.csv...
# Loaded 39 questions.
# Initializing PathwayVectorClient on host 127.0.0.1 and port 8011...
# PathwayVectorClient initialized.
# Creating CohereRerank compressor...
# Compressor created.
# Initializing OpenAI LLM...
# OpenAI LLM initialized.
# Creating chat prompt template...
# Chat prompt template created.
# Total number of rows:  39
#
# Processing question ID 0: How has Apple's total net sales changed over time?
# Retrieving relevant documents for query: How has Apple's total net sales changed over time?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 1008
# Estimated output tokens: 565
#
# Processing question ID 1: What are the major factors contributing to the change in Apple's gross margin in the most recent 10-Q compared to the previous quarters?
# Retrieving relevant documents for query: What are the major factors contributing to the change in Apple's gross margin in the most recent 10-Q compared to the previous quarters?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 610
# Estimated output tokens: 508
#
# Processing question ID 2: Has there been any significant change in Apple's operating expenses over the reported quarters? If so, what are the key drivers for this change?
# Retrieving relevant documents for query: Has there been any significant change in Apple's operating expenses over the reported quarters? If so, what are the key drivers for this change?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 485
# Estimated output tokens: 283
#
# Processing question ID 3: How has Apple's revenue from iPhone sales fluctuated across quarters?
# Retrieving relevant documents for query: How has Apple's revenue from iPhone sales fluctuated across quarters?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 644
# Estimated output tokens: 372
#
# Processing question ID 4: Can any trends be identified in Apple's Services segment revenue over the reported periods?
# Retrieving relevant documents for query: Can any trends be identified in Apple's Services segment revenue over the reported periods?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 606
# Estimated output tokens: 396
#
# Processing question ID 5: What is the impact of foreign exchange rates on Apple's financial performance? List this out separately for each reported period.
# Retrieving relevant documents for query: What is the impact of foreign exchange rates on Apple's financial performance? List this out separately for each reported period.
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 525
# Estimated output tokens: 302
#
# Processing question ID 6: Are there any notable changes in Apple's liquidity position or cash flows as reported in these 10-Qs?
# Retrieving relevant documents for query: Are there any notable changes in Apple's liquidity position or cash flows as reported in these 10-Qs?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 905
# Estimated output tokens: 475
#
# Processing question ID 7: How does Apple's R&D expenditure in the most recent quarter compare to previous quarters and what implications might this have?
# Retrieving relevant documents for query: How does Apple's R&D expenditure in the most recent quarter compare to previous quarters and what implications might this have?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 687
# Estimated output tokens: 491
#
# Processing question ID 8: What legal proceedings or contingencies are disclosed in these 10-Qs and how might they potentially impact Apple?
# Retrieving relevant documents for query: What legal proceedings or contingencies are disclosed in these 10-Qs and how might they potentially impact Apple?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 659
# Estimated output tokens: 500
#
# Processing question ID 9: Has Apple engaged in any significant share repurchase activities in the reported quarters and what are the financial implications of these activities?
# Retrieving relevant documents for query: Has Apple engaged in any significant share repurchase activities in the reported quarters and what are the financial implications of these activities?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 477
# Estimated output tokens: 430
#
# Processing question ID 10: What is the effective tax rate reported by Apple in these quarters and how does it compare across the periods?
# Retrieving relevant documents for query: What is the effective tax rate reported by Apple in these quarters and how does it compare across the periods?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 717
# Estimated output tokens: 319
#
# Processing question ID 11: Does Apple report any significant new business acquisitions or divestitures in these 10-Qs?
# Retrieving relevant documents for query: Does Apple report any significant new business acquisitions or divestitures in these 10-Qs?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 561
# Estimated output tokens: 167
#
# Processing question ID 12: How have Apple's inventory levels changed across these quarters and what might this indicate about their supply chain management?
# Retrieving relevant documents for query: How have Apple's inventory levels changed across these quarters and what might this indicate about their supply chain management?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 692
# Estimated output tokens: 578
#
# Processing question ID 13: Are there any significant changes or new disclosures in Apple's accounting policies as reported in these 10-Qs?
# Retrieving relevant documents for query: Are there any significant changes or new disclosures in Apple's accounting policies as reported in these 10-Qs?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 641
# Estimated output tokens: 192
#
# Processing question ID 14: Summarize the risk factors to Apple's business, and how they have changed over the reporting period
# Retrieving relevant documents for query: Summarize the risk factors to Apple's business, and how they have changed over the reporting period
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 661
# Estimated output tokens: 258
#
# Processing question ID 15: What was the gross margin for Apple in the latest 10-Q report?
# Retrieving relevant documents for query: What was the gross margin for Apple in the latest 10-Q report?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 527
# Estimated output tokens: 147
#
# Processing question ID 16: How did Apple's operating expenses for Q1 2023 compare to its revenue for the same quarter?
# Retrieving relevant documents for query: How did Apple's operating expenses for Q1 2023 compare to its revenue for the same quarter?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 1005
# Estimated output tokens: 294
#
# Processing question ID 17: In the second quarter of 2023, what was the primary driver behind the change in Apple's net income?
# Retrieving relevant documents for query: In the second quarter of 2023, what was the primary driver behind the change in Apple's net income?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 622
# Estimated output tokens: 204
#
# Processing question ID 18: For the latest quarter, what was the total revenue generated from Apple's iPhone sales?
# Retrieving relevant documents for query: For the latest quarter, what was the total revenue generated from Apple's iPhone sales?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 977
# Estimated output tokens: 81
#
# Processing question ID 19: What percentage of Apple's total revenue did the Services segment contribute in Q3 2023?
# Retrieving relevant documents for query: What percentage of Apple's total revenue did the Services segment contribute in Q3 2023?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 626
# Estimated output tokens: 69
#
# Processing question ID 20: How did foreign exchange rates specifically affect Apple's financial performance in the most recent 10-Q?
# Retrieving relevant documents for query: How did foreign exchange rates specifically affect Apple's financial performance in the most recent 10-Q?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 521
# Estimated output tokens: 406
#
# Processing question ID 21: What was Apple's cash flow from operating activities as reported in the Q3 2022 10-Q?
# Retrieving relevant documents for query: What was Apple's cash flow from operating activities as reported in the Q3 2022 10-Q?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 1950
# Estimated output tokens: 154
#
# Processing question ID 22: In the first quarter of 2023, how much did Apple spend on research and development, and what was the focus of this expenditure?
# Retrieving relevant documents for query: In the first quarter of 2023, how much did Apple spend on research and development, and what was the focus of this expenditure?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 679
# Estimated output tokens: 62
#
# Processing question ID 23: What specific legal proceedings or potential liabilities were mentioned in Apple's Q2 2023 10-Q, and what is their potential impact?
# Retrieving relevant documents for query: What specific legal proceedings or potential liabilities were mentioned in Apple's Q2 2023 10-Q, and what is their potential impact?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 498
# Estimated output tokens: 217
#
# Processing question ID 24: Did Apple report any share repurchase activities in its Q3 2023 10-Q, and if so, what was the scale of these buybacks?
# Retrieving relevant documents for query: Did Apple report any share repurchase activities in its Q3 2023 10-Q, and if so, what was the scale of these buybacks?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 598
# Estimated output tokens: 65
#
# Processing question ID 25: What changes in debt structure or interest expenses did Apple disclose in the Q1 2023 10-Q?
# Retrieving relevant documents for query: What changes in debt structure or interest expenses did Apple disclose in the Q1 2023 10-Q?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 297
# Estimated output tokens: 169
#
# Processing question ID 26: What effective tax rate did Apple report in its latest quarterly filing, and how does this compare to the statutory tax rate?
# Retrieving relevant documents for query: What effective tax rate did Apple report in its latest quarterly filing, and how does this compare to the statutory tax rate?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 638
# Estimated output tokens: 148
#
# Processing question ID 27: Were there any significant acquisitions or divestitures reported by Apple in the Q2 2023 10-Q?
# Retrieving relevant documents for query: Were there any significant acquisitions or divestitures reported by Apple in the Q2 2023 10-Q?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 326
# Estimated output tokens: 120
#
# Processing question ID 28: How did Apple's inventory levels in the Q3 2022 report reflect on their supply chain efficiency?
# Retrieving relevant documents for query: How did Apple's inventory levels in the Q3 2022 report reflect on their supply chain efficiency?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 443
# Estimated output tokens: 445
#
# Processing question ID 29: What significant accounting policy changes, if any, did Apple disclose in its most recent 10-Q?
# Retrieving relevant documents for query: What significant accounting policy changes, if any, did Apple disclose in its most recent 10-Q?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 639
# Estimated output tokens: 138
#
# Processing question ID 30: In Apple's Q1 2023 10-Q, what is the correlation between Apple's R&D expenditure and the new products or services introduced by the company?
# Retrieving relevant documents for query: In Apple's Q1 2023 10-Q, what is the correlation between Apple's R&D expenditure and the new products or services introduced by the company?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 515
# Estimated output tokens: 287
#
# Processing question ID 31: For Apple's Q2 2023 report, analyze the relationship between Apple's revenue from international markets and its segment on foreign currency risk to understand the company's exposure to currency fluctuations.
# Retrieving relevant documents for query: For Apple's Q2 2023 report, analyze the relationship between Apple's revenue from international markets and its segment on foreign currency risk to understand the company's exposure to currency fluctuations.
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 359
# Estimated output tokens: 427
#
# Processing question ID 32: From Apple's most recent 10-Q, how do the insights from the liquidity and capital resources section correlate with the reported changes in Apple's cash flow from operations?
# Retrieving relevant documents for query: From Apple's most recent 10-Q, how do the insights from the liquidity and capital resources section correlate with the reported changes in Apple's cash flow from operations?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 1423
# Estimated output tokens: 469
#
# Processing question ID 33: In Apple's Q3 2023 10-Q, analyze how the reported changes in Apple's inventory levels relate to the discussion in their supply chain and logistics section.
# Retrieving relevant documents for query: In Apple's Q3 2023 10-Q, analyze how the reported changes in Apple's inventory levels relate to the discussion in their supply chain and logistics section.
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 329
# Estimated output tokens: 538
#
# Processing question ID 34: From the latest 10-Q, how does Apple's discussion on market risk in the financial section align with the risk factors mentioned in the company's business overview?
# Retrieving relevant documents for query: From the latest 10-Q, how does Apple's discussion on market risk in the financial section align with the risk factors mentioned in the company's business overview?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 607
# Estimated output tokens: 436
#
# Processing question ID 35: In Apple's Q1 2023 10-Q, combine the data on Apple's debt instruments from the financial statements with the management discussion to understand their debt management strategy.
# Retrieving relevant documents for query: In Apple's Q1 2023 10-Q, combine the data on Apple's debt instruments from the financial statements with the management discussion to understand their debt management strategy.
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 390
# Estimated output tokens: 485
#
# Processing question ID 36: In the most recent 10-Q, analyze how Apple's reported tax rate in the financial statements section correlates with the discussion on tax contingencies in the notes.
# Retrieving relevant documents for query: In the most recent 10-Q, analyze how Apple's reported tax rate in the financial statements section correlates with the discussion on tax contingencies in the notes.
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 620
# Estimated output tokens: 508
#
# Processing question ID 37: From Apple's Q3 2023 10-Q, how does the information in the operational expenses section relate to the insights shared in Apple's segment reporting?
# Retrieving relevant documents for query: From Apple's Q3 2023 10-Q, how does the information in the operational expenses section relate to the insights shared in Apple's segment reporting?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 459
# Estimated output tokens: 461
#
# Processing question ID 38: In the latest 10-Q, how does the revenue from new product launches by Apple compare with the company's marketing and advertising expenses?
# Retrieving relevant documents for query: In the latest 10-Q, how does the revenue from new product launches by Apple compare with the company's marketing and advertising expenses?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 761
# Estimated output tokens: 219
# Saving evaluation results to eval_results/basic_rag_enhancedParser.json...
# Evaluation results saved to eval_results/basic_rag_enhancedParser.json

# %% [markdown]
# ### Unstructured HiRes Parser

# %%
import json
import time
import os
import pandas as pd
from dotenv import load_dotenv
from langchain.retrievers.contextual_compression import ContextualCompressionRetriever
from langchain_cohere import CohereRerank
from langchain_community.vectorstores import PathwayVectorClient
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains import LLMChain
import tiktoken  # For token counting

# Load environment variables
def load_environment_variables():
    """Load environment variables from a .env file."""
    print("Loading environment variables...")
    load_dotenv()
    os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
    print("Environment variables loaded.")

# Initialize Pathway retriever
def create_pathway_client(host="127.0.0.1", port=8011, k=10):
    """Initialize PathwayVectorClient and return as retriever."""
    print(f"Initializing PathwayVectorClient on host {host} and port {port}...")
    client = PathwayVectorClient(host=host, port=port)
    print("PathwayVectorClient initialized.")
    return client.as_retriever(search_kwargs={"k": k})

# Retrieve relevant documents
def retrieve_relevant_documents(retriever, query):
    """Retrieve relevant documents based on the given query."""
    print(f"Retrieving relevant documents for query: {query}")
    try:
        docs = retriever.get_relevant_documents(query)
        print(f"Retrieved {len(docs)} chunks.")
        return docs
    except Exception as e:
        print(f"Error retrieving documents: {e}")
        return []

# Create document compressor
def create_compressor(model="rerank-english-v3.0"):
    """Create and return a CohereRerank compressor."""
    print("Creating CohereRerank compressor...")
    compressor = CohereRerank(model=model, top_n=5)
    print("Compressor created.")
    return compressor

# Compress retrieved documents
def compress_documents(retriever, query, compressor):
    """Compress relevant documents using the provided compressor."""
    print("Compressing retrieved chunks...")
    compression_retriever = ContextualCompressionRetriever(
        base_compressor=compressor, base_retriever=retriever
    )
    try:
        compressed_docs = compression_retriever.invoke(query)
        print(f"Compressed to {len(compressed_docs)} chunks.")
        return compressed_docs
    except Exception as e:
        print(f"Error during compression: {e}")
        return []

# Initialize OpenAI LLM
def create_llm():
    """Create and return an OpenAI LLM instance."""
    print("Initializing OpenAI LLM...")
    llm = ChatOpenAI(
        model="gpt-4o-mini",
        temperature=0,
        max_tokens=None,
        timeout=45,
        max_retries=2,
    )
    print("OpenAI LLM initialized.")
    return llm

# Create ChatPromptTemplate for Q&A
def create_chat_prompt():
    """Create and return a chat prompt template for Q&A."""
    print("Creating chat prompt template...")
    chat_prompt = ChatPromptTemplate.from_messages(
        [
            (
                "system",
                "You are a helpful assistant. Answer the following question based only on the provided context.\n"
                "Provide a step-by-step explanation, and reference the source details using metadata.\n\n"
                "<context>\n{context}\n</context>",
            ),
            ("human", "{question}"),
        ]
    )
    print("Chat prompt template created.")
    return chat_prompt

# Token counting function
def count_tokens(text, model="o200k_base"):
    """Estimate token count for given text using tiktoken."""
    tokenizer = tiktoken.get_encoding(model)
    tokens = tokenizer.encode(text)
    return len(tokens)

# Generate answer
def get_answer(context, question, chain):
    """Generate an answer based on the context and question using the LLM chain."""
    print("Generating answer for the question...")
    try:
        input_tokens = count_tokens(context) + count_tokens(question)
        print(f"Estimated input tokens: {input_tokens}")

        # Invoke the LLM chain with structured input
        answer = chain.invoke({"context": context, "question": question})
        
        output_tokens = count_tokens(answer.content)
        print(f"Estimated output tokens: {output_tokens}")
        
        return answer.content
    except Exception as e:
        print(f"Error generating answer: {e}")
        return None

# Main execution logic
def main():
    # Load environment variables
    load_environment_variables()

    # Load the dataset
    file_path = 'AAPL_10Q_dataset/aapl_qna_data.csv'
    print(f"Loading dataset from {file_path}...")
    data = pd.read_csv(file_path)
    print(f"Loaded {len(data)} questions.")

    # Initialize Pathway retriever, compressor, LLM, and chat prompt
    retriever = create_pathway_client()
    compressor = create_compressor()
    llm = create_llm()
    chat_prompt = create_chat_prompt()

    # Create the LLM chain
    chain = chat_prompt | llm

    # Prepare results storage
    results = []
    print("Total number of rows: ", len(data))
    # Loop over each question in the dataset
    for idx, row in data.iterrows():
        question = row['Question']
        gt_answer = row.get('Answer', "Ground truth answer not provided")
        
        print(f"\nProcessing question ID {idx}: {question}")

        # Step 1: Retrieve relevant documents
        retrieved_docs = retrieve_relevant_documents(retriever, question)
        if not retrieved_docs:
            print(f"No documents retrieved for query ID {idx}.")
            continue

        # Step 2: Compress retrieved documents
        compressed_docs = compress_documents(retriever, question, compressor)
        # compressed_docs = retrieved_docs

        # Prepare the context from compressed documents
        context = "\n".join([doc.page_content for doc in compressed_docs if doc.page_content])

        # Step 3: Generate an answer with retry logic
        answer = get_answer(context, question, chain)
        if answer is None:
            print(f"Retrying for question ID {idx} due to no initial response...")
            time.sleep(50)  # Wait 50 seconds before retrying
            answer = get_answer(context, question, chain)

        # Structure retrieved context in a list of dictionaries as per your format
        retrieved_context = [
            {"doc_id": doc.metadata.get("doc_id", "unknown"), "text": doc.page_content}
            for doc in compressed_docs
        ]
        
        # Append to results
        results.append({
            "query_id": str(idx).zfill(3),
            "question": question,
            "gt_answer": gt_answer,
            "response": answer,
            "retrieved_context": retrieved_context
        })

    # Save the results to a JSON file
    output_path = 'eval_results/basic_rag_hiResParser.json'
    print(f"Saving evaluation results to {output_path}...")
    with open(output_path, 'w') as f:
        json.dump({"results": results}, f, indent=4)

    print(f"Evaluation results saved to {output_path}")

# Run main function
if __name__ == "__main__":
    main()
# Out:
# Loading environment variables...
# Environment variables loaded.
# Loading dataset from AAPL_10Q_dataset/aapl_qna_data.csv...
# Loaded 39 questions.
# Initializing PathwayVectorClient on host 127.0.0.1 and port 8011...
# PathwayVectorClient initialized.
# Creating CohereRerank compressor...
# Compressor created.
# Initializing OpenAI LLM...
# OpenAI LLM initialized.
# Creating chat prompt template...
# Chat prompt template created.
# Total number of rows:  39
#
# Processing question ID 0: How has Apple's total net sales changed over time?
# Retrieving relevant documents for query: How has Apple's total net sales changed over time?
# /tmp/ipykernel_131618/1057249705.py:35: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   docs = retriever.get_relevant_documents(query)
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 823
# Estimated output tokens: 620
#
# Processing question ID 1: What are the major factors contributing to the change in Apple's gross margin in the most recent 10-Q compared to the previous quarters?
# Retrieving relevant documents for query: What are the major factors contributing to the change in Apple's gross margin in the most recent 10-Q compared to the previous quarters?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 110
# Estimated output tokens: 464
#
# Processing question ID 2: Has there been any significant change in Apple's operating expenses over the reported quarters? If so, what are the key drivers for this change?
# Retrieving relevant documents for query: Has there been any significant change in Apple's operating expenses over the reported quarters? If so, what are the key drivers for this change?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 111
# Estimated output tokens: 373
#
# Processing question ID 3: How has Apple's revenue from iPhone sales fluctuated across quarters?
# Retrieving relevant documents for query: How has Apple's revenue from iPhone sales fluctuated across quarters?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 416
# Estimated output tokens: 406
#
# Processing question ID 4: Can any trends be identified in Apple's Services segment revenue over the reported periods?
# Retrieving relevant documents for query: Can any trends be identified in Apple's Services segment revenue over the reported periods?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 444
# Estimated output tokens: 377
#
# Processing question ID 5: What is the impact of foreign exchange rates on Apple's financial performance? List this out separately for each reported period.
# Retrieving relevant documents for query: What is the impact of foreign exchange rates on Apple's financial performance? List this out separately for each reported period.
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 101
# Estimated output tokens: 139
#
# Processing question ID 6: Are there any notable changes in Apple's liquidity position or cash flows as reported in these 10-Qs?
# Retrieving relevant documents for query: Are there any notable changes in Apple's liquidity position or cash flows as reported in these 10-Qs?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 105
# Estimated output tokens: 354
#
# Processing question ID 7: How does Apple's R&D expenditure in the most recent quarter compare to previous quarters and what implications might this have?
# Retrieving relevant documents for query: How does Apple's R&D expenditure in the most recent quarter compare to previous quarters and what implications might this have?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 106
# Estimated output tokens: 347
#
# Processing question ID 8: What legal proceedings or contingencies are disclosed in these 10-Qs and how might they potentially impact Apple?
# Retrieving relevant documents for query: What legal proceedings or contingencies are disclosed in these 10-Qs and how might they potentially impact Apple?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 106
# Estimated output tokens: 316
#
# Processing question ID 9: Has Apple engaged in any significant share repurchase activities in the reported quarters and what are the financial implications of these activities?
# Retrieving relevant documents for query: Has Apple engaged in any significant share repurchase activities in the reported quarters and what are the financial implications of these activities?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 290
# Estimated output tokens: 493
#
# Processing question ID 10: What is the effective tax rate reported by Apple in these quarters and how does it compare across the periods?
# Retrieving relevant documents for query: What is the effective tax rate reported by Apple in these quarters and how does it compare across the periods?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 105
# Estimated output tokens: 206
#
# Processing question ID 11: Does Apple report any significant new business acquisitions or divestitures in these 10-Qs?
# Retrieving relevant documents for query: Does Apple report any significant new business acquisitions or divestitures in these 10-Qs?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 94
# Estimated output tokens: 303
#
# Processing question ID 12: How have Apple's inventory levels changed across these quarters and what might this indicate about their supply chain management?
# Retrieving relevant documents for query: How have Apple's inventory levels changed across these quarters and what might this indicate about their supply chain management?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 104
# Estimated output tokens: 383
#
# Processing question ID 13: Are there any significant changes or new disclosures in Apple's accounting policies as reported in these 10-Qs?
# Retrieving relevant documents for query: Are there any significant changes or new disclosures in Apple's accounting policies as reported in these 10-Qs?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 105
# Estimated output tokens: 331
#
# Processing question ID 14: Summarize the risk factors to Apple's business, and how they have changed over the reporting period
# Retrieving relevant documents for query: Summarize the risk factors to Apple's business, and how they have changed over the reporting period
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 103
# Estimated output tokens: 270
#
# Processing question ID 15: What was the gross margin for Apple in the latest 10-Q report?
# Retrieving relevant documents for query: What was the gross margin for Apple in the latest 10-Q report?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 99
# Estimated output tokens: 298
#
# Processing question ID 16: How did Apple's operating expenses for Q1 2023 compare to its revenue for the same quarter?
# Retrieving relevant documents for query: How did Apple's operating expenses for Q1 2023 compare to its revenue for the same quarter?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 104
# Estimated output tokens: 263
#
# Processing question ID 17: In the second quarter of 2023, what was the primary driver behind the change in Apple's net income?
# Retrieving relevant documents for query: In the second quarter of 2023, what was the primary driver behind the change in Apple's net income?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 166
# Estimated output tokens: 82
#
# Processing question ID 18: For the latest quarter, what was the total revenue generated from Apple's iPhone sales?
# Retrieving relevant documents for query: For the latest quarter, what was the total revenue generated from Apple's iPhone sales?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 769
# Estimated output tokens: 94
#
# Processing question ID 19: What percentage of Apple's total revenue did the Services segment contribute in Q3 2023?
# Retrieving relevant documents for query: What percentage of Apple's total revenue did the Services segment contribute in Q3 2023?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 309
# Estimated output tokens: 149
#
# Processing question ID 20: How did foreign exchange rates specifically affect Apple's financial performance in the most recent 10-Q?
# Retrieving relevant documents for query: How did foreign exchange rates specifically affect Apple's financial performance in the most recent 10-Q?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 102
# Estimated output tokens: 289
#
# Processing question ID 21: What was Apple's cash flow from operating activities as reported in the Q3 2022 10-Q?
# Retrieving relevant documents for query: What was Apple's cash flow from operating activities as reported in the Q3 2022 10-Q?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 105
# Estimated output tokens: 219
#
# Processing question ID 22: In the first quarter of 2023, how much did Apple spend on research and development, and what was the focus of this expenditure?
# Retrieving relevant documents for query: In the first quarter of 2023, how much did Apple spend on research and development, and what was the focus of this expenditure?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 186
# Estimated output tokens: 101
#
# Processing question ID 23: What specific legal proceedings or potential liabilities were mentioned in Apple's Q2 2023 10-Q, and what is their potential impact?
# Retrieving relevant documents for query: What specific legal proceedings or potential liabilities were mentioned in Apple's Q2 2023 10-Q, and what is their potential impact?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 111
# Estimated output tokens: 331
#
# Processing question ID 24: Did Apple report any share repurchase activities in its Q3 2023 10-Q, and if so, what was the scale of these buybacks?
# Retrieving relevant documents for query: Did Apple report any share repurchase activities in its Q3 2023 10-Q, and if so, what was the scale of these buybacks?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 116
# Estimated output tokens: 277
#
# Processing question ID 25: What changes in debt structure or interest expenses did Apple disclose in the Q1 2023 10-Q?
# Retrieving relevant documents for query: What changes in debt structure or interest expenses did Apple disclose in the Q1 2023 10-Q?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 106
# Estimated output tokens: 289
#
# Processing question ID 26: What effective tax rate did Apple report in its latest quarterly filing, and how does this compare to the statutory tax rate?
# Retrieving relevant documents for query: What effective tax rate did Apple report in its latest quarterly filing, and how does this compare to the statutory tax rate?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 350
# Estimated output tokens: 199
#
# Processing question ID 27: Were there any significant acquisitions or divestitures reported by Apple in the Q2 2023 10-Q?
# Retrieving relevant documents for query: Were there any significant acquisitions or divestitures reported by Apple in the Q2 2023 10-Q?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 107
# Estimated output tokens: 235
#
# Processing question ID 28: How did Apple's inventory levels in the Q3 2022 report reflect on their supply chain efficiency?
# Retrieving relevant documents for query: How did Apple's inventory levels in the Q3 2022 report reflect on their supply chain efficiency?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 104
# Estimated output tokens: 344
#
# Processing question ID 29: What significant accounting policy changes, if any, did Apple disclose in its most recent 10-Q?
# Retrieving relevant documents for query: What significant accounting policy changes, if any, did Apple disclose in its most recent 10-Q?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 104
# Estimated output tokens: 235
#
# Processing question ID 30: In Apple's Q1 2023 10-Q, what is the correlation between Apple's R&D expenditure and the new products or services introduced by the company?
# Retrieving relevant documents for query: In Apple's Q1 2023 10-Q, what is the correlation between Apple's R&D expenditure and the new products or services introduced by the company?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 116
# Estimated output tokens: 358
#
# Processing question ID 31: For Apple's Q2 2023 report, analyze the relationship between Apple's revenue from international markets and its segment on foreign currency risk to understand the company's exposure to currency fluctuations.
# Retrieving relevant documents for query: For Apple's Q2 2023 report, analyze the relationship between Apple's revenue from international markets and its segment on foreign currency risk to understand the company's exposure to currency fluctuations.
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 119
# Estimated output tokens: 365
#
# Processing question ID 32: From Apple's most recent 10-Q, how do the insights from the liquidity and capital resources section correlate with the reported changes in Apple's cash flow from operations?
# Retrieving relevant documents for query: From Apple's most recent 10-Q, how do the insights from the liquidity and capital resources section correlate with the reported changes in Apple's cash flow from operations?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 116
# Estimated output tokens: 408
#
# Processing question ID 33: In Apple's Q3 2023 10-Q, analyze how the reported changes in Apple's inventory levels relate to the discussion in their supply chain and logistics section.
# Retrieving relevant documents for query: In Apple's Q3 2023 10-Q, analyze how the reported changes in Apple's inventory levels relate to the discussion in their supply chain and logistics section.
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 117
# Estimated output tokens: 368
#
# Processing question ID 34: From the latest 10-Q, how does Apple's discussion on market risk in the financial section align with the risk factors mentioned in the company's business overview?
# Retrieving relevant documents for query: From the latest 10-Q, how does Apple's discussion on market risk in the financial section align with the risk factors mentioned in the company's business overview?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 115
# Estimated output tokens: 376
#
# Processing question ID 35: In Apple's Q1 2023 10-Q, combine the data on Apple's debt instruments from the financial statements with the management discussion to understand their debt management strategy.
# Retrieving relevant documents for query: In Apple's Q1 2023 10-Q, combine the data on Apple's debt instruments from the financial statements with the management discussion to understand their debt management strategy.
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 118
# Estimated output tokens: 495
#
# Processing question ID 36: In the most recent 10-Q, analyze how Apple's reported tax rate in the financial statements section correlates with the discussion on tax contingencies in the notes.
# Retrieving relevant documents for query: In the most recent 10-Q, analyze how Apple's reported tax rate in the financial statements section correlates with the discussion on tax contingencies in the notes.
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 117
# Estimated output tokens: 409
#
# Processing question ID 37: From Apple's Q3 2023 10-Q, how does the information in the operational expenses section relate to the insights shared in Apple's segment reporting?
# Retrieving relevant documents for query: From Apple's Q3 2023 10-Q, how does the information in the operational expenses section relate to the insights shared in Apple's segment reporting?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 115
# Estimated output tokens: 427
#
# Processing question ID 38: In the latest 10-Q, how does the revenue from new product launches by Apple compare with the company's marketing and advertising expenses?
# Retrieving relevant documents for query: In the latest 10-Q, how does the revenue from new product launches by Apple compare with the company's marketing and advertising expenses?
# Retrieved 10 chunks.
# Compressing retrieved chunks...
# Compressed to 5 chunks.
# Generating answer for the question...
# Estimated input tokens: 111
# Estimated output tokens: 322
# Saving evaluation results to eval_results/basic_rag_hiResParser.json...
# Evaluation results saved to eval_results/basic_rag_hiResParser.json

# %% [markdown]
# ### Print Stats

# %%
import os
from dotenv import load_dotenv
from langchain_community.vectorstores import PathwayVectorClient

def load_environment_variables():
    """Load environment variables from a .env file."""
    print("Loading environment variables...")
    load_dotenv()
    print("Environment variables loaded.")

def calculate_average_chunk_size(client, sample_size=10000):
    """
    Estimate the average chunk size based on a sample of documents from the vector store.
    
    Args:
        client (PathwayVectorClient): The client connected to the Pathway Vector Store.
        sample_size (int): Number of documents to sample for estimating chunk size.
    
    Returns:
        int: Estimated average chunk size.
    """
    try:
        # Retrieve a sample of documents
        sample_docs = client.similarity_search(".", k=sample_size)
        
        # Calculate the average document length in the sample
        total_length = sum(len(doc.page_content) for doc in sample_docs if doc.page_content)
        average_chunk_size = total_length // len(sample_docs)
        print(f"Estimated average chunk size from sample: {average_chunk_size} characters.")
        
        return average_chunk_size
    
    except Exception as e:
        print(f"Error retrieving sample documents: {e}")
        return None

def calculate_total_chunks(client, estimated_chunk_size):
    """
    Calculate the total number of chunks in the Pathway Vector Store using the estimated chunk size.
    
    Args:
        client (PathwayVectorClient): The client connected to the Pathway Vector Store.
        estimated_chunk_size (int): Estimated size of each chunk in characters.
    
    Returns:
        int: Estimated total number of chunks in the database.
    """
    try:
        # Try to get total characters from the vector store statistics
        stats = client.get_vectorstore_statistics()
        total_chars = stats.get("total_character_count")  # Hypothetical field
        
        if total_chars:
            print(f"Total characters from statistics: {total_chars}")
            total_chunks = total_chars // estimated_chunk_size + (1 if total_chars % estimated_chunk_size != 0 else 0)
            return total_chunks
        else:
            print("Character count not available in statistics. Proceeding with document iteration.")
    
    except Exception as e:
        print(f"Error retrieving statistics: {e}")
    
    # Fall back to summing document lengths if statistics aren't available
    try:
        all_docs = client.similarity_search("how are you", k=10000)  # Retrieve a large number of docs (adjust as needed)
        
        total_length = sum(len(doc.page_content) for doc in all_docs if doc.page_content)
        print(f"Total characters by iterating documents: {total_length}")
        
        total_chunks = total_length // estimated_chunk_size + (1 if total_length % estimated_chunk_size != 0 else 0)
        return total_chunks
    
    except Exception as e:
        print(f"Error retrieving documents: {e}")
        return 0

# Load environment variables (if needed)
load_environment_variables()

# Initialize PathwayVectorClient
client = PathwayVectorClient(host="127.0.0.1", port=8011)

# Step 1: Estimate average chunk size based on sample documents
estimated_chunk_size = calculate_average_chunk_size(client)
if estimated_chunk_size is None:
    print("Could not determine an estimated chunk size.")

# Step 2: Calculate total chunks in the vector store based on estimated chunk size
total_chunks = calculate_total_chunks(client, estimated_chunk_size)
print(f"Total estimated chunks in the database: {total_chunks}")
# Out:
# Loading environment variables...
# Environment variables loaded.
# Error retrieving sample documents: HTTPConnectionPool(host='127.0.0.1', port=8011): Read timed out. (read timeout=3)
# Could not determine an estimated chunk size.
